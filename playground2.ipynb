# %% [markdown]
# ### Playground 2

# %% [markdown]
# Deck of Cards:

# %%
import time
from random import shuffle
from typing import List

# %%
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return f'{self.rank} of {self.suit}'

# %%
class Deck:
    
    def __init__(self):
        self.all_cards = [Card(suit, rank) for suit in suits for rank in ranks]
                
    def shuffle(self):
        shuffle(self.all_cards)
        
    def deal_one(self):
        if not self.all_cards:
            raise ValueError('No cards left in the deck!')
        return self.all_cards.pop()

# %%
class Player:
    
    def __init__(self,name):
        self.name = name
        # A new player has no cards
        self.all_cards: List[Card] = []
        
    def remove_one(self):
        # Index 0 will represent the "top" of the deck...
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)  # .extend() adds the new list to the existing list
        else:
            self.all_cards.append(new_cards)  # .append() would nest the new list to a non-empty list
    
    
    def __str__(self):
        if len(self.all_cards) == 1:
            return f'Player {self.name} has {len(self.all_cards)} card.'
        else:
            return f'Player {self.name} has {len(self.all_cards)} cards.'

# %%
## print all card instances in the deck
#for i in Deck().all_cards:
    #print(i)

# %%
## test...

new_deck = Deck()
new_deck.shuffle()
my_card = new_deck.deal_one()

# %%
## COM player setup:
idx = 0

player_select = ['Gambit', 'Hisoka', 'Hawkins', 'Yugi', 'Kaiba', 'Joker']

# %%
shuffle(player_select)

player_names = [player_select.pop(), player_select.pop()]

for i,j in enumerate(player_names):
    player1 = Player(player_names[idx])
    player2 = Player(player_names[(idx + 1) % 2])

def choose_ur_char(player_select):
    shuffle(player_select)

    px = [player_select.pop(), player_select.pop()]

    for i,j in enumerate(px):
        px[i] = Player(px[i])
        print(f'Player {i+1}: {px[i].name}')

choose_ur_char(player_select)

# %%
def choose_ur_char(player_select):
    global px

    shuffle(player_select)

    px = [player_select.pop(), player_select.pop()]

    for i,j in enumerate(px):
        px[i] = Player(px[i])
        print(f'Player {i+1}: {px[i].name}')

choose_ur_char(player_select)
# Out:
# Player 1: Joker
# Player 2: Yugi

# %%
len(px[0].all_cards) == 0
# Out:
# True

# %%
COMdeck = Deck()
COMdeck.shuffle()

for i in range(26):
    px[idx].add_cards(COMdeck.deal_one())
    px[(idx + 1) %2].add_cards(COMdeck.deal_one())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 COMdeck = Deck()
#       2 COMdeck.shuffle()
# ----> 4 for i in int(range(len(COMdeck.all_cards)/2)):
#       5     px[idx].add_cards(COMdeck.deal_one())
#       6     px[(idx + 1) %2].add_cards(COMdeck.deal_one())
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
## game logic:

game_on = True
turn_ct = 0


while game_on:
    print('Round {turn_ct}')
    time.sleep(1.2)

    px[idx].all_cards = [px[idx].append(px[idx].remove_one())]

    while at_war:




    if len(px[idx].all_cards) == 0:
        print(f'{px[idx].name} (player {i}) is out of cards...\n{px[(idx + 1) %2].name} (player {(idx + 1) %2}) wins!')
        game_on == False
        break

    if len(px[(idx + 1) %2].all_cards) == 0:
        print(f'{px[(idx + 1) %2].name} (player {((idx + 1) %2) + 1}) is out of cards...\n{px[idx + 1].name} (player {idx + 1}) wins!')
        game_on == False
        break    

    else:
        turn_ct += 1
        idx = (idx + 1) % 2

# %%
## COM player setup: v2
idx = 0

player_select = ['Gambit', 'Hisoka', 'Hawkins', 'Yugi', 'Kaiba', 'Joker']

def choose_ur_char(player_select):
    global player1, player2

    shuffle(player_select)

    player1 = Player(player_select.pop())
    player2 = Player(player_select.pop())

choose_ur_char(player_select)

# %%
player1.all_cards[-1].value
# Out:
# 8

# %%
## COM deck setup: v2

COMdeck = Deck()
COMdeck.shuffle()

for i in range(26):
    player1.add_cards(COMdeck.deal_one())
    player2.add_cards(COMdeck.deal_one())

# %%
## game logic: v2

print('I hope you know... This. Means. WAR!!!')
time.sleep(2)
print('Let\'s play a fkcing card game...')
time.sleep(2)
cc = 5
game_on = True
turn_ct = 0


while game_on:

    turn_ct += 1
    print(f'Round {turn_ct}')
    time.sleep(0.5)

    p1_cards = []
    p1_cards.append(player1.remove_one())

    p2_cards = []
    p2_cards.append(player2.remove_one())

    at_war = True

    while at_war:

        if p1_cards[-1].value > p2_cards[-1].value:

            player1.add_cards(p1_cards)
            player1.add_cards(p2_cards)
            at_war = False
        
        elif p1_cards[-1].value < p2_cards[-1].value:

            player2.add_cards(p2_cards)
            player2.add_cards(p1_cards)
            at_war = False
        
        else:

            print('WAR!')
            time.sleep(1.5)

            if len(player1.all_cards) < cc:

                print(f'{player1.name} (P1) does not have enough cards ({cc} req\'d) to declare War...\n{player2.name.upper()} (P2) WINS!')
                game_on = False
                break

            elif len(player2.all_cards) < cc:

                print(f'{player2.name} (P2) does not have enough cards ({cc} req\'d) to declare War...\n{player1.name.upper()} (P2) WINS!')
                game_on = False
                break

            else:

                for i in range(cc):

                    p1_cards.append(player1.remove_one())
                    p2_cards.append(player2.remove_one())

    if len(player1.all_cards) == 0:

        print(f'{player1.name} (P1) is out of cards...\n{player2.name.upper()} (P2) WINS!')
        game_on == False
        break

    if len(player2.all_cards) == 0:

        print(f'{player2.name} (P2) is out of cards...\n{player1.name.upper()} (P1) WINS!')
        game_on == False
        break
# Out:
# I hope you know... This. Means. WAR!!!
# Let's play a fkcing card game...
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# WAR!
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# Round 28
# Round 29
# Round 30
# Round 31
# Round 32
# Round 33
# Round 34
# Round 35
# Round 36
# Round 37
# Round 38
# Round 39
# Round 40
# Round 41
# Round 42
# Round 43
# Round 44
# WAR!
# WAR!
# Round 45
# WAR!
# Round 46
# Round 47
# Round 48
# WAR!
# Round 49
# Round 50
# Round 51
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# Round 57
# Round 58
# Round 59
# Round 60
# WAR!
# WAR!
# Round 61
# Round 62
# Round 63
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# Round 73
# Round 74
# Round 75
# Round 76
# Round 77
# Round 78
# Round 79
# Round 80
# ...
